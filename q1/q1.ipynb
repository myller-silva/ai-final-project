# %%
# %pip install numpy 
# %pip install matplotlib 
# %pip install scikit-learn 
# %pip install torch
# Out:
# Requirement already satisfied: numpy in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (2.6.0)
# Requirement already satisfied: filelock in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from torch) (2025.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mylle\onedrive\documentos\github\trabalho-ia\.venv\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importações

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# # Parâmetros

# %%
n_samples = 100
x = np.random.uniform(-10, 10, n_samples)
epsilon = np.random.normal(0, 2, n_samples)
y = 3 * x + 5 + epsilon

# %% [markdown]
# # Visualização dos dados

# %%
plt.scatter(x, y, label='Dados Sintéticos')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # Dividir os dados em treino e teste

# %%
test_size = 0.2
random_state = 42
x_train, x_test, y_train, y_test = train_test_split(
    x, y, 
    test_size=test_size,
    random_state=random_state
)

# %% [markdown]
# # Visualização dos dados de treino e teste

# %%
plt.scatter(x_train, y_train, label='Treino', color='blue')
plt.scatter(x_test, y_test, label='Teste', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # Implementação dos modelos de regressão linear

# %% [markdown]
# ## Solução de mínimos quadrados (pseudo-inversa)

# %% [markdown]
# Adicionando uma coluna de uns para o termo de bias

# %%
X_train = np.vstack([x_train, np.ones(len(x_train))]).T
X_test = np.vstack([x_test, np.ones(len(x_test))]).T

# %% [markdown]
# Calculando a pseudo-inversa

# %%
theta = np.linalg.pinv(X_train) @ y_train

# %% [markdown]
# Fazendo previsões

# %%
y_pred_ls = X_test @ theta

# %% [markdown]
# Visualização dos resultados

# %%
plt.scatter(x_test, y_test, label='Dados Reais', color='blue')
plt.plot(x_test, y_pred_ls, label='Previsão Mínimos Quadrados', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ## Rede neural com uma camada treinada via gradiente descendente

# %% [markdown]
# Convertendo os dados para tensores do PyTorch

# %%
x_train_tensor = torch.tensor(x_train, dtype=torch.float32).view(-1, 1)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
x_test_tensor = torch.tensor(x_test, dtype=torch.float32).view(-1, 1)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %% [markdown]
# Definindo o modelo

# %%
class LinearRegression(nn.Module):
    def __init__(self):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

model = LinearRegression()

# %% [markdown]
# Definindo a função de perda e o otimizador

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# Treinando o modelo

# %%
num_epochs = 1000
model.train()
for epoch in range(num_epochs):
    # Forward pass
    outputs = model(x_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    
    # Backward pass e otimização
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [100/1000], Loss: 3.1055
# Epoch [200/1000], Loss: 2.8715
# Epoch [300/1000], Loss: 2.8674
# Epoch [400/1000], Loss: 2.8673
# Epoch [500/1000], Loss: 2.8673
# Epoch [600/1000], Loss: 2.8673
# Epoch [700/1000], Loss: 2.8673
# Epoch [800/1000], Loss: 2.8673
# Epoch [900/1000], Loss: 2.8673
# Epoch [1000/1000], Loss: 2.8673

# %% [markdown]
# Fazendo previsões

# %%
model.eval()
with torch.no_grad():
    y_pred_nn = model(x_test_tensor).numpy()

# %% [markdown]
# Visualização dos resultados

# %%
plt.scatter(x_test, y_test, label='Dados Reais', color='blue')
plt.plot(x_test, y_pred_nn, label='Previsão Rede Neural', color='green')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# # Soluções obtidas pelos dois métodos

# %% [markdown]
# Mínimos Quadrados

# %%
print(f"y = {theta[0]:.4f}x + {theta[1]:.4f}")
# Out:
# y = 2.9774x + 4.3038

# %% [markdown]
# Rede neural

# %%
weights = model.linear.weight.item()
bias = model.linear.bias.item()
print(f"y = {weights:.4f}x + {bias:.4f}")
# Out:
# y = 2.9774x + 4.3038
